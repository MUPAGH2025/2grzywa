# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from open_atmos_jupyter_utils import show_plot

# %% [markdown]
# <H2 align = "center">Zapoznanie z projektem oraz wizualizacja warunków początkowych</H2>
